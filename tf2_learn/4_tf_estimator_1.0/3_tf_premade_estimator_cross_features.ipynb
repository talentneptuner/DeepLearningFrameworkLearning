# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn 
import pandas as pd
import os, gc, sys, time
import tensorflow as tf
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn')
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %% [markdown]
# ## **2.1数据集titanic**

# %%
train_file = './data/titanic/titanic_train.csv'
eval_file = './data/titanic/titanic_eval.csv'

train_df = pd.read_csv(train_file)
eval_df = pd.read_csv(eval_file)

train_df.head(5)
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0         0    male  22.0                   1      0   7.2500  Third  unknown
# 1         1  female  38.0                   1      0  71.2833  First        C
# 2         1  female  26.0                   0      0   7.9250  Third  unknown
# 3         1  female  35.0                   1      0  53.1000  First        C
# 4         0    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
y_train = train_df.pop('survived')
y_eval = eval_df.pop('survived')

train_df.head(10)
# Out:
#       sex   age  n_siblings_spouses  parch     fare   class     deck  \
# 0    male  22.0                   1      0   7.2500   Third  unknown
# 1  female  38.0                   1      0  71.2833   First        C
# 2  female  26.0                   0      0   7.9250   Third  unknown
# 3  female  35.0                   1      0  53.1000   First        C
# 4    male  28.0                   0      0   8.4583   Third  unknown
# 5    male   2.0                   3      1  21.0750   Third  unknown
# 6  female  27.0                   0      2  11.1333   Third  unknown
# 7  female  14.0                   1      0  30.0708  Second  unknown
# 8  female   4.0                   1      1  16.7000   Third        G
# 9    male  20.0                   0      0   8.0500   Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y
# 5  Southampton     n
# 6  Southampton     n
# 7    Cherbourg     n
# 8  Southampton     n
# 9  Southampton     y

# %% [markdown]
# ## **2.2 feature_column的使用**
# **离散特征**: one-hot编码
# **连续特征**: 分桶

# %%
categorical_columns = ['sex', 'n_siblings_spouses', 'parch', 'class',
                       'deck', 'embark_town', 'alone']
numeric_columns = ['age', 'fare']

feature_columns = []

# 将类别特征转换为one-hot的特征
for categorical_column in categorical_columns:
    vocab = train_df[categorical_column].unique()
    # 使用tf.feature_columns下的api
    feature_columns.append(tf.feature_column.indicator_column(tf.feature_column.categorical_column_with_vocabulary_list(categorical_column, vocab)))
for numeric_column in numeric_columns:
    feature_columns.append(tf.feature_column.numeric_column(numeric_column, dtype=tf.float32))

# %% [markdown]
# **交叉特征**

# %%
feature_columns.append(tf.feature_column.indicator_column(tf.feature_column.crossed_column(['age', 'sex'],
                                 hash_bucket_size=100 # hash_bucket_size用来控制cross后特征变得很多
                                                                                          )))

# %%
def make_dataset(data_df, label_df, epochs = 10, shuffle = True, batch_size = 32):
    dataset = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))
    if shuffle:
        dataset.shuffle(10000)
    dataset = dataset.repeat(epochs).batch(batch_size)
    return dataset

# %% [markdown]
# ## **1.3  tf自带estimator**

# %% [markdown]
# 有两种训练的模式
# - 直接调用fit的方法
# - 将model转换为estimator，然后再进行训练

# %%
output_dir = 'linear_model_cf'
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

linear_estimator = tf.estimator.LinearClassifier(model_dir=output_dir, 
                                                     n_classes = 2,
                                                   feature_columns=feature_columns)
linear_estimator.train(input_fn = lambda : make_dataset(train_df, y_train, epochs=100))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'linear_model_cf', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001FBB318CF98>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\dp_gpu_tf2\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\dp_gpu_tf2\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\dp_gpu_tf2\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:518: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\dp_gpu_tf2\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:4276: IndicatorColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\dp_gpu_tf2\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:4331: CrossedColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\dp_gpu_tf2\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:4331: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\dp_gpu_tf2\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\dp_gpu_tf2\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\ftrl.py:143: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into linear_model_cf\model.ckpt.
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 160.626
# INFO:tensorflow:loss = 0.45826253, step = 100 (0.623 sec)
# INFO:tensorflow:global_step/sec: 222.322
# INFO:tensorflow:loss = 0.5656878, step = 200 (0.451 sec)
# INFO:tensorflow:global_step/sec: 228.4
# INFO:tensorflow:loss = 0.42663288, step = 300 (0.438 sec)
# INFO:tensorflow:global_step/sec: 221.34
# INFO:tensorflow:loss = 0.41105792, step = 400 (0.452 sec)
# INFO:tensorflow:global_step/sec: 225.827
# INFO:tensorflow:loss = 0.36762518, step = 500 (0.443 sec)
# INFO:tensorflow:global_step/sec: 204.211
# INFO:tensorflow:loss = 0.47515434, step = 600 (0.489 sec)
# INFO:tensorflow:global_step/sec: 226.337
# INFO:tensorflow:loss = 0.44350073, step = 700 (0.443 sec)
# INFO:tensorflow:global_step/sec: 205.037
# INFO:tensorflow:loss = 0.3080526, step = 800 (0.487 sec)
# INFO:tensorflow:global_step/sec: 161.466
# INFO:tensorflow:loss = 0.21116355, step = 900 (0.620 sec)
# INFO:tensorflow:global_step/sec: 220.853
# INFO:tensorflow:loss = 0.4818802, step = 1000 (0.453 sec)
# INFO:tensorflow:global_step/sec: 219.704
# INFO:tensorflow:loss = 0.4188639, step = 1100 (0.455 sec)
# INFO:tensorflow:global_step/sec: 218.447
# INFO:tensorflow:loss = 0.3222772, step = 1200 (0.458 sec)
# INFO:tensorflow:global_step/sec: 217.973
# INFO:tensorflow:loss = 0.26673537, step = 1300 (0.459 sec)
# INFO:tensorflow:global_step/sec: 201.617
# INFO:tensorflow:loss = 0.4770333, step = 1400 (0.496 sec)
# INFO:tensorflow:global_step/sec: 221.575
# INFO:tensorflow:loss = 0.4510255, step = 1500 (0.451 sec)
# INFO:tensorflow:global_step/sec: 197.356
# INFO:tensorflow:loss = 0.2683142, step = 1600 (0.507 sec)
# INFO:tensorflow:global_step/sec: 217.27
# INFO:tensorflow:loss = 0.36541516, step = 1700 (0.460 sec)
# INFO:tensorflow:global_step/sec: 218.448
# INFO:tensorflow:loss = 0.30465466, step = 1800 (0.458 sec)
# INFO:tensorflow:global_step/sec: 219.174
# INFO:tensorflow:loss = 0.29064974, step = 1900 (0.456 sec)
# INFO:tensorflow:Saving checkpoints for 1960 into linear_model_cf\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3088312.

# %%
linear_estimator.evaluate(input_fn = lambda : make_dataset(
    eval_df, y_eval, epochs = 1, shuffle = False))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-25T14:24:38Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from linear_model_cf\model.ckpt-1960
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-25-14:24:39
# INFO:tensorflow:Saving dict for global step 1960: accuracy = 0.8030303, accuracy_baseline = 0.625, auc = 0.8584634, auc_precision_recall = 0.7755953, average_loss = 0.4578519, global_step = 1960, label/mean = 0.375, loss = 0.44055963, precision = 0.7326733, prediction/mean = 0.37647587, recall = 0.74747473
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1960: linear_model_cf\model.ckpt-1960
# {'accuracy': 0.8030303,
#  'accuracy_baseline': 0.625,
#  'auc': 0.8584634,
#  'auc_precision_recall': 0.7755953,
#  'average_loss': 0.4578519,
#  'label/mean': 0.375,
#  'loss': 0.44055963,
#  'precision': 0.7326733,
#  'prediction/mean': 0.37647587,
#  'recall': 0.74747473,
#  'global_step': 1960}

# %%
output_dir = 'dnn_model_cf'
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

dnn_estimator = tf.estimator.DNNClassifier(model_dir=output_dir, 
                                           n_classes = 2,
                                           hidden_units=[128, 128],
                                           activation_fn=tf.nn.relu,
                                           optimizer='Adam',
                                           feature_columns=feature_columns)
dnn_estimator.train(input_fn = lambda : make_dataset(train_df, y_train, epochs=100))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'dnn_model_cf', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001FBB46C1898>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into dnn_model_cf\model.ckpt.
# INFO:tensorflow:loss = 2.6313884, step = 0
# INFO:tensorflow:global_step/sec: 161.461
# INFO:tensorflow:loss = 0.4583365, step = 100 (0.621 sec)
# INFO:tensorflow:global_step/sec: 165.309
# INFO:tensorflow:loss = 0.4341594, step = 200 (0.604 sec)
# INFO:tensorflow:global_step/sec: 229.67
# INFO:tensorflow:loss = 0.44900677, step = 300 (0.436 sec)
# INFO:tensorflow:global_step/sec: 167.38
# INFO:tensorflow:loss = 0.3969208, step = 400 (0.596 sec)
# INFO:tensorflow:global_step/sec: 186.834
# INFO:tensorflow:loss = 0.25550696, step = 500 (0.537 sec)
# INFO:tensorflow:global_step/sec: 148.064
# INFO:tensorflow:loss = 0.37535, step = 600 (0.674 sec)
# INFO:tensorflow:global_step/sec: 183.29
# INFO:tensorflow:loss = 0.37138528, step = 700 (0.546 sec)
# INFO:tensorflow:global_step/sec: 186.088
# INFO:tensorflow:loss = 0.14072815, step = 800 (0.538 sec)
# INFO:tensorflow:global_step/sec: 187.087
# INFO:tensorflow:loss = 0.143333, step = 900 (0.534 sec)
# INFO:tensorflow:global_step/sec: 185.858
# INFO:tensorflow:loss = 0.27484092, step = 1000 (0.537 sec)
# INFO:tensorflow:global_step/sec: 174.148
# INFO:tensorflow:loss = 0.19429047, step = 1100 (0.575 sec)
# INFO:tensorflow:global_step/sec: 188.881
# INFO:tensorflow:loss = 0.22952734, step = 1200 (0.530 sec)
# INFO:tensorflow:global_step/sec: 181.203
# INFO:tensorflow:loss = 0.09134765, step = 1300 (0.551 sec)
# INFO:tensorflow:global_step/sec: 191.084
# INFO:tensorflow:loss = 0.2202706, step = 1400 (0.524 sec)
# INFO:tensorflow:global_step/sec: 191.384
# INFO:tensorflow:loss = 0.17089778, step = 1500 (0.523 sec)
# INFO:tensorflow:global_step/sec: 154.969
# INFO:tensorflow:loss = 0.08127717, step = 1600 (0.645 sec)
# INFO:tensorflow:global_step/sec: 168.134
# INFO:tensorflow:loss = 0.2944172, step = 1700 (0.595 sec)
# INFO:tensorflow:global_step/sec: 180.963
# INFO:tensorflow:loss = 0.08439515, step = 1800 (0.553 sec)
# INFO:tensorflow:global_step/sec: 158.59
# INFO:tensorflow:loss = 0.07716442, step = 1900 (0.630 sec)
# INFO:tensorflow:Saving checkpoints for 1960 into dnn_model_cf\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.1782756.

# %%
dnn_estimator.evaluate(input_fn = lambda : make_dataset(
    eval_df, y_eval, epochs = 1, shuffle = False))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-25T14:25:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from dnn_model_cf\model.ckpt-1960
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-25-14:25:06
# INFO:tensorflow:Saving dict for global step 1960: accuracy = 0.78409094, accuracy_baseline = 0.625, auc = 0.8408938, auc_precision_recall = 0.76810956, average_loss = 0.75915486, global_step = 1960, label/mean = 0.375, loss = 0.7029121, precision = 0.6944444, prediction/mean = 0.4201552, recall = 0.75757575
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1960: dnn_model_cf\model.ckpt-1960
# {'accuracy': 0.78409094,
#  'accuracy_baseline': 0.625,
#  'auc': 0.8408938,
#  'auc_precision_recall': 0.76810956,
#  'average_loss': 0.75915486,
#  'label/mean': 0.375,
#  'loss': 0.7029121,
#  'precision': 0.6944444,
#  'prediction/mean': 0.4201552,
#  'recall': 0.75757575,
#  'global_step': 1960}

# %% [markdown]
# estimator在model之外额外完成了很多操作，或保存tensorboard和model
